# %% [markdown]
# <a href="https://colab.research.google.com/github/ANURAG-DVS/Text_Summarization_NLP/blob/main/Text_Summarization_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ...

# %%
from datasets import load_dataset
dataset=load_dataset('abisee/cnn_dailymail','3.0.0')
# Out:
# ...
# Generating test split:   0%|          | 0/11490 [00:00<?, ? examples/s]

# %%
from datasets import load_dataset

dataset = load_dataset('abisee/cnn_dailymail','3.0.0')  # Replace with the actual dataset name

# Access the training data (assuming a 'train' split exists)
train_data = dataset['train']

# Print information about the data
print(train_data.features)  # View data features and formats
print(len(train_data))  # Get the number of data points
# Out:
# {'article': Value(dtype='string', id=None), 'highlights': Value(dtype='string', id=None), 'id': Value(dtype='string', id=None)}
# 287113

# %%
# !pip install datasets
import nltk
import re

def clean_data(dataset, cleaning_steps):
  """
  This function cleans and preprocesses a dataset for text summarization.

  Args:
      dataset (dict): The dataset object loaded from Hugging Face.
          The structure of this dictionary might vary depending on the dataset.
      cleaning_steps (list): A list of cleaning steps to be performed.
          Valid options include:
              * "lowercase": Convert text to lowercase.
              * "remove_html": Remove HTML tags using regular expressions.
              * "remove_punctuation": Remove punctuation marks.
              * "remove_stopwords": Remove stop words using NLTK's stop words list (optional).
              * "custom_cleaning" (optional): Define your own cleaning function here.

  Returns:
      list: A list of cleaned datapoints.
  """

  cleaned_dataset = [] # Initialize as a list to store cleaned datapoints

  # Access the data split you want to clean (e.g., 'train')
  data_split = dataset['train']  # Modify this based on your dataset structure

  for datapoint in data_split:
    text = datapoint['article']  # Modify this based on the column containing text data

    # Perform cleaning steps
    for step in cleaning_steps:
      if step == "lowercase":
        text = text.lower()
      elif step == "remove_html":
        text = re.sub(r'<[^>]*>', '', text)
      elif step == "remove_punctuation":
        text = ''.join([c for c in text if not c.isalnum()])
      elif step == "remove_stopwords":
        stop_words = nltk.corpus.stopwords.words('english')
        text = ' '.join([word for word in text.split() if word not in stop_words])
      elif step == "custom_cleaning":
        # Define your custom cleaning function here (optional)
        text = custom_cleaning_function(text)
      else:
        print(f"Warning: Unknown cleaning step '{step}'. Ignoring.")

    # Update the cleaned text in the datapoint
    datapoint['text'] = text

    # Add the cleaned datapoint to the cleaned dataset
    cleaned_dataset.append(datapoint) # Append the modified datapoint to the list

  return cleaned_dataset

# Example usage (replace with your actual dataset loading logic)
from datasets import load_dataset

dataset_name = "abisee/cnn_dailymail"  # Replace with the actual dataset name
dataset = load_dataset('abisee/cnn_dailymail', '3.0.0')

# Choose the cleaning steps you want to perform
cleaning_steps = ["lowercase", "remove_html", "remove_punctuation"]  # Modify as needed

cleaned_dataset = clean_data(dataset, cleaning_steps)

# Use the cleaned dataset for further processing (e.g., train-test split, tokenization)

# %%
import nltk
import re

def clean_data(dataset, cleaning_steps):
  """
  This function cleans and preprocesses a dataset for text summarization.

  Args:
      dataset (dict): The dataset object loaded from Hugging Face.
      cleaning_steps (list): A list of cleaning steps to be performed.
          Valid options include:
              * "lowercase": Convert text to lowercase.
              * "remove_html": Remove HTML tags using regular expressions.
              * "remove_punctuation": Remove punctuation marks (optional).
              * "remove_stopwords": Remove stop words using NLTK's stop words list (optional).
              * "normalize_numbers" (optional): Normalize numbers to a standard format.
              * "spelling_correction" (optional): Fix typos and grammatical errors.
              * "custom_cleaning" (optional): Define your own cleaning function here.

  Returns:
      list: A list of cleaned datapoints.
  """

  cleaned_dataset = [] # Initialize as a list to store cleaned datapoints

  # Access the data split you want to clean (e.g., 'train')
  data_split = dataset['train']  # Modify this based on your dataset structure

  for datapoint in data_split:
    text = datapoint['article']  # Access the 'article' key instead of 'text'

    # Perform cleaning steps
    for step in cleaning_steps:
      if step == "lowercase":
        text = text.lower()
      elif step == "remove_html":
        text = re.sub(r'<[^>]*>', '', text)
      elif step == "remove_punctuation":
        text = ''.join([c for c in text if not c.isalnum()])
      elif step == "remove_stopwords":
        stop_words = nltk.corpus.stopwords.words('english')
        text = ' '.join([word for word in text.split() if word not in stop_words])
      elif step == "normalize_numbers":
        # Define your custom function for number normalization (optional)
        text = normalize_numbers(text)  # Replace with your function
      elif step == "spelling_correction":
        # Use libraries like PyEnchant for spelling correction (optional)
        text = spellcheck(text)  # Replace with your function using PyEnchant
      elif step == "custom_cleaning":
        # Define your custom cleaning function here (optional)
        text = custom_cleaning_function(text)
      else:
        print(f"Warning: Unknown cleaning step '{step}'. Ignoring.")

    # Update the cleaned text in the datapoint (create a new key if needed)
    datapoint['cleaned_article'] = text # Create a new key to store the cleaned article

    # Add the cleaned datapoint to the cleaned dataset
    cleaned_dataset.append(datapoint) # Append the modified datapoint to the list

  return cleaned_dataset

# Example usage (replace with your actual dataset loading logic)
from datasets import load_dataset

dataset_name = "abisee/cnn_dailymail"  # Replace with the actual dataset name
dataset = load_dataset('abisee/cnn_dailymail', '3.0.0')

# Choose the cleaning steps you want to perform
cleaning_steps = ["lowercase", "remove_html", "remove_punctuation"]  # Modify as needed
# You can optionally add "normalize_numbers" or "spelling_correction"

cleaned_dataset = clean_data(dataset, cleaning_steps)

# Use the cleaned dataset for further processing
